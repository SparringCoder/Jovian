# %% [markdown]
# # Problem 1:

# %%
project_name='python-practice-assignment'

# %%
name = 'Sneha Bhandari'

# %%
age = 22

# %%
has_android_phone = True

# %%
name, age, has_android_phone
# Out:
# ('Sneha Bhandari', 22, True)

# %%
person = {'Name':name,'Age':age,'HasAndroidPhone':has_android_phone}
person
# Out:
# {'Name': 'Sneha Bhandari', 'Age': 22, 'HasAndroidPhone': True}

# %%
# printing with if-else to check if person has android phone or iphone
print("{} is aged {}, and owns an {}.".format(
    person["Name"], 
    person["Age"], 
    "Android phone" if person["HasAndroidPhone"] else "iPhone"
))
# Out:
# Sneha Bhandari is aged 22, and owns an Android phone.

# %%
#making for loop to go through all keys in the dictonary
for x in person:
  print('The key {} has the value {} of the type {}.'.format(x,person[x],type(person[x])))
# Out:
# The key Name has the value Sneha Bhandari of the type <class 'str'>.
# The key Age has the value 22 of the type <class 'int'>.
# The key HasAndroidPhone has the value True of the type <class 'bool'>.

# %% [markdown]
# #Problem 2:

# %%
#creating my_list dictionary
my_list = {'Fav_color':'White','No_pets':2,'Prev_programming_exp':True}

my_list
# Out:
# {'Fav_color': 'White', 'No_pets': 2, 'Prev_programming_exp': True}

# %%
# print favourite color
print('My favorite color is', my_list['Fav_color'])
# print number of pets
print('I have {} pet(s).'.format(my_list['No_pets']))

#writing if statement to check previous programming experience
if my_list['Prev_programming_exp']==True: 
  print('I have previous programming experience.')
else:
  print('I do not have previous programming experience.')
# Out:
# My favorite color is White
# I have 2 pet(s).
# I have previous programming experience.

# %%
# adding favourite number in my_list
my_list.update({'Fav_number':7})
my_list
# Out:
# {'Fav_color': 'White',
#  'No_pets': 2,
#  'Prev_programming_exp': True,
#  'Fav_number': 7}

# %%
print("The list has {} elements.".format(len(my_list)))
# Out:
# The list has 4 elements.

# %% [markdown]
# #Problem 3:

# %%
#setting variable to store final answer
sum_of_numbers = 0

# calculating sum of all the numbers divisible by 7 between 18 and 534

for x in range(18, 534):
  if x % 7 == 0:
    sum_of_numbers += x 
print('The sum of all the numbers divisible by 7 between 18 and 534 is', sum_of_numbers)
# Out:
# The sum of all the numbers divisible by 7 between 18 and 534 is 20461

# %%
#optional question
ticket_price = 200
total_tickets = 29 + 12
total_ticket_revenue = total_tickets * ticket_price
cost_of_operation = 5000*2

profit = cost_of_operation < total_ticket_revenue
if profit ==True:
   total_profit = total_ticket_revenue - cost_of_operation
else:
  total_loss = cost_of_operation = total_ticket_revenue

#printing results
if profit == True:
    print("The company makes an overall profit of {} dollars".format(total_profit))
else:
    print("The company makes an overall loss of {} dollars".format(total_loss))
# Out:
# The company makes an overall loss of 8200 dollars

# %% [markdown]
# #Problem 5 -Twitter Sentiment Analysis:

# %%
#list of tweets
tweets = [
    "Wow, what a great day today!! #sunshine",
    "I feel sad about the things going on around us. #covid19",
    "I'm really excited to learn Python with @JovianML #zerotopandas",
    "This is a really nice song. #linkinpark",
    "The python programming language is useful for data science",
    "Why do bad things happen to me?",
    "Apple announces the release of the new iPhone 12. Fans are excited.",
    "Spent my day with family!! #happy",
    "Check out my blog post on common string operations in Python. #zerotopandas",
    "Freecodecamp has great coding tutorials. #skillup"
]

# %%
#counting number of tweets
number_of_tweets = len(tweets)
number_of_tweets
# Out:
# 10

# %%
#list of happy and sad words
happy_words = ['great', 'excited', 'happy', 'nice', 'wonderful', 'amazing', 'good', 'best']
sad_words = ['sad', 'bad', 'tragic', 'unhappy', 'worst']

#creating variable to store number of happy tweets
number_of_happy_tweets = 0

# creating loop to count happy tweets

for sentence in tweets:
  for word in happy_words:
    if word in sentence:
      number_of_happy_tweets += 1

print("Number of happy tweets:", number_of_happy_tweets)
# Out:
# Number of happy tweets: 6

# %%
#solving for number of sad tweets
number_of_sad_tweets = 0 

for sentence in tweets:
  for word in sad_words:
    if word in sentence:
      number_of_sad_tweets += 1

print("Number of sad tweets:", number_of_sad_tweets)
# Out:
# Number of sad tweets: 2

# %%
#calculating fraction of sad tweets
sad_fraction = number_of_sad_tweets/number_of_tweets

print("The fraction of sad tweets is:", sad_fraction)
# Out:
# The fraction of sad tweets is: 0.2

# %%
#calculating fraction of happy tweets 
happy_fraction = number_of_happy_tweets / number_of_tweets

print("The fraction of happy tweets is:", happy_fraction)
# Out:
# The fraction of happy tweets is: 0.6

# %%
#calculating sentiment score

sentiment_score = happy_fraction - sad_fraction

print("The sentiment score for the given tweets is", sentiment_score)
# Out:
# The sentiment score for the given tweets is 0.39999999999999997

# %%
#calculating number of neutral tweets
number_of_neutral_tweets = number_of_tweets - (number_of_happy_tweets + number_of_sad_tweets)

#calculating neutral fraction
neutral_fraction = number_of_neutral_tweets/number_of_tweets

print('The fraction of neutral tweets is', neutral_fraction)
# Out:
# The fraction of neutral tweets is 0.2
